# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
decision = pd.read_excel("/content/decision_result.xlsx")
multi = pd.read_excel("/content/final_predict (1).xlsx")
xgb = pd.read_excel("/content/xgb_result.xlsx")

# %%
decision
# Out:
#      세부주소           보증금
# 0       0  17562.990533
# 1       1  25115.985488
# 2       2  17562.990533
# 3       3  25115.985488
# 4       4  20411.734655
# ..    ...           ...
# 177   177   4660.000000
# 178   178   4660.000000
# 179   179   7777.969512
# 180   180   4250.000000
# 181   181   4250.000000
#
# [182 rows x 2 columns]

# %%
multi
# Out:
#                       세부주소                단지명          예측집값
# 0        세종특별자치시 새롬동2202-3  새뜸마을10단지(더샵힐스테이트)  16402.004431
# 1        세종특별자치시 새롬동2202-4  새뜸마을11단지(더샵힐스테이트)  23143.767891
# 2          세종특별자치시 새롬동85-1           새뜸마을13단지  17971.766176
# 3        세종특별자치시 새롬동2202-5  새뜸마을14단지(더샵힐스테이트)  22548.952012
# 4        세종특별자치시 새롬동2202-6     새뜸마을1단지(메이저시티)  19290.847787
# ..                     ...                ...           ...
# 177  세종특별자치시 부강면 부강리973-13                블루빌   2520.471273
# 178  세종특별자치시 부강면 부강리973-13                블루빌   4893.313740
# 179  세종특별자치시 부강면 부강리401-48                 주연  11540.903703
# 180   세종특별자치시 부강면 부강리970-3                 청솔   9017.217909
# 181   세종특별자치시 부강면 부강리970-3                 청솔  10094.974107
#
# [182 rows x 3 columns]

# %%
xgb
# Out:
#      Unnamed: 0           보증금
# 0             0  17576.667969
# 1             1  27692.080078
# 2             2  17817.800781
# 3             3  25617.960938
# 4             4  21098.720703
# ..          ...           ...
# 177         177   4573.813965
# 178         178   2758.791992
# 179         179   8827.397461
# 180         180   6488.535156
# 181         181   6620.393066
#
# [182 rows x 2 columns]

# %%
plt.figure(figsize=(20, 6)) # (1,1), (2,2), (3,3) 의 데이터를 넣어서 그린다. 
plt.plot(decision["보증금"]) 
plt.show()

# %%
plt.figure(figsize=(20, 6)) # (1,1), (2,2), (3,3) 의 데이터를 넣어서 그린다. 
plt.plot(multi["예측집값"]) 
plt.show()

# %%
plt.figure(figsize=(20, 6)) # (1,1), (2,2), (3,3) 의 데이터를 넣어서 그린다. 
plt.plot(xgb["보증금"]) 
plt.show()

# %%
plt.figure(figsize=(20, 6))
plt.plot(decision["보증금"], label="decision")
plt.plot(multi["예측집값"], label="multi")
plt.plot(xgb["보증금"], label = "xgb")
plt.legend()
plt.show()
