# %%
import pandas as pd

apt_df = pd.read_excel("/content/2020new (2).xlsx")
apt_df.head()
# Out:
#              세부주소        단지명   정부청사거리   층  ...    SNS긍정률      전용면적  도시형생활주택    보증금
# 0  세종특별자치시 고운동 가-  가락마을 19단지  3.81209   5  ...  0.553994   84.6972        0  24000
# 1   세종특별자치시 고운동가-  가락마을 19단지  3.81209   2  ...  0.553994   84.9544        0  21000
# 2   세종특별자치시 고운동가-  가락마을 19단지  3.81209  10  ...  0.553994   59.6506        0  15000
# 3   세종특별자치시 고운동가-  가락마을 19단지  3.81209   7  ...  0.553994  105.7788        0  18000
# 4   세종특별자치시 고운동가-  가락마을 19단지  3.81209  11  ...  0.553994  105.6138        0  23000
#
# [5 rows x 19 columns]

# %%
import pandas as pd


df = pd.read_excel("/content/2020new_dataclean1.xlsx")
df.head()
# Out:
#    Unnamed: 0            세부주소        단지명  ...      전용면적  도시형생활주택    보증금
# 0           0  세종특별자치시 고운동 가-  가락마을 19단지  ...   84.6972        0  24000
# 1           1   세종특별자치시 고운동가-  가락마을 19단지  ...   84.9544        0  21000
# 2           2   세종특별자치시 고운동가-  가락마을 19단지  ...   59.6506        0  15000
# 3           3   세종특별자치시 고운동가-  가락마을 19단지  ...  105.7788        0  18000
# 4           4   세종특별자치시 고운동가-  가락마을 19단지  ...  105.6138        0  23000
#
# [5 rows x 20 columns]

# %%
from sklearn.model_selection import train_test_split

x = apt_df[['층', '계약년월', '건축년도', '정부청사거리','전입인구', 'COFIX',
       '부동산심리지수', '소비자물가지수',	'SNS긍정률', '전용면적', '도시형생활주택']]

y = apt_df[['보증금']]

pd.get_dummies(x, columns=['도시형생활주택'])

x_train, x_test, y_train, y_test = train_test_split(x, y, train_size=0.7, test_size=0.3)

# %%
from sklearn.model_selection import train_test_split

x2 = df[['층', '계약년월', '건축년도', '정부청사거리','전입인구', 'COFIX',
       '부동산심리지수', '소비자물가지수',	'SNS긍정률', '전용면적', '도시형생활주택']]

y2 = df[['보증금']]

pd.get_dummies(x2, columns=['도시형생활주택'])

x2_train, x2_test, y2_train, y2_test = train_test_split(x2, y2, train_size=0.7, test_size=0.3)

# %%
# 박사님 조언
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score

model = LinearRegression()

model = Lasso(alpha=1.0)

model.fit(x_train, y_train)

y_pred = model.predict(x_test)

mean_squared_error(y_test, y_pred)
r2_score(y_test, y_pred)

model.intercept_
model.coef_
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-0e904b4c1f96> in <module>()
#       5 model = LinearRegression()
#       6
# ----> 7 model = Lasso(alpha=1.0)
#       8
#       9 model.fit(x_train, y_train)
#
# NameError: name 'Lasso' is not defined

# %%
from sklearn.linear_model import LinearRegression

mlr = LinearRegression()
mlr.fit(x_train, y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
from sklearn.linear_model import LinearRegression

mlr2 = LinearRegression()
mlr2.fit(x2_train, y2_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
y_predict = mlr.predict(x_test)

# %%
y2_predict = mlr2.predict(x2_test)

# %%
import matplotlib.pyplot as plt

plt.scatter(y_test, y_predict, alpha = 0.4)
plt.xlabel("Actual Rent")
plt.ylabel('Predicted Rent')
plt.title("MULTIPLE LINEAR REGRESSION")
plt.show()

# %%
import matplotlib.pyplot as plt

plt.scatter(y2_test, y2_predict, alpha = 0.4)
plt.xlabel("Actual Rent")
plt.ylabel('Predicted Rent')
plt.title("MULTIPLE LINEAR REGRESSION")
plt.show()

# %%
print(mlr.coef_)
# Out:
# [[ 3.17300962e+01  9.40573098e+00  2.17533198e+02 -5.98863829e+02
#    4.85473445e-01 -1.55978704e+04 -8.29353369e+01  2.16497095e-01
#    1.71404506e+03  1.54924302e+02 -2.20354532e+03]]

# %%
plt.scatter(apt_df[['층']], apt_df[['보증금']], alpha=0.4)
plt.show()

# %%
# 건축년도가 최근일수록 보증금이 높았다. 
plt.scatter(apt_df[['건축년도']], apt_df[['보증금']], alpha=0.4)
plt.show()

# %%
# 정부청사와 거리가 가까울수록 보증금이 높았다.
plt.scatter(apt_df[['정부청사거리']], apt_df[['보증금']], alpha=0.4)
plt.show()

# %%
plt.scatter(apt_df[['SNS긍정률']], apt_df[['보증금']], alpha=0.4)
plt.show()

# %%
plt.scatter(apt_df[['COFIX']], apt_df[['보증금']], alpha=0.4)
plt.show()

# %%
# 전용면적이 클수록 보증금이 높았다.
plt.scatter(apt_df[['전용면적']], apt_df[['보증금']], alpha=0.4)
plt.show()

# %%
# 도시형생활주택이 아닌 아파트일수록 보증금이 컸다.
plt.scatter(apt_df[['도시형생활주택']], apt_df[['보증금']], alpha=0.4)
plt.show()

# %%
print(mlr.score(x_train,y_train))
# Out:
# 0.6099879431824394

# %%
from sklearn.linear_model import Lasso

model = Lasso(alpha=1.0)

##########모델 학습

model.fit(x_train, y_train)

##########모델 검증

print(model.score(x_train, y_train)) #0.919925874068437

print(model.score(x_test, y_test)) #0.7719888251895852

##########모델 예측


y_predict = model.predict(x_test)
print(y_predict[0]) #8.545955714194164
# Out:
# 0.6099682935939366
# 0.6093859543494287
# 18792.669844025746
